# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
metrics_df = pd.read_csv('./../../results/FakeNewsDetection/fake_news_detection_results.csv', index_col=0)
metrics_df
# Out:
#    Unnamed: 0.1 model features lang  accuracy  precision    recall        f1
# 0           0.0    NB    tfidf   en  0.857333   0.858966  0.854375  0.856664
# 1           0.0    LR    tfidf   en  0.949333   0.968707  0.928667  0.948264
# 2           0.0   MLP    tfidf   en  0.954000   0.936487  0.973064  0.954425
# 3           0.0   SVM    tfidf   en  0.970000   0.989316  0.948770  0.968619
# 4           0.0    NB    count   en  0.886333   0.867997  0.908356  0.887718
# 5           0.0    LR    count   en  0.951333   0.964191  0.940492  0.952194
# 6           0.0   MLP    count   en  0.963333   0.968037  0.960518  0.964263
# 7           0.0   SVM    count   en  0.921333   0.996100  0.846817  0.915412
# 0           NaN    NB    tfidf   es  0.940333   0.907846  0.979181  0.942165
# 0           NaN    LR    tfidf   es  0.977667   0.984375  0.970529  0.977403
# 0           NaN   MLP    tfidf   es  0.985000   0.978681  0.991228  0.984915
# 0           NaN   SVM    tfidf   es  0.989000   0.992558  0.985225  0.988878
# 0           NaN    NB    count   es  0.919333   0.886391  0.963672  0.923418
# 0           NaN    LR    count   es  0.986000   0.986702  0.985392  0.986047
# 0           NaN   MLP    count   es  0.980667   0.988583  0.972902  0.980680
# 0           NaN   SVM    count   es  0.967333   0.982265  0.952381  0.967092
# 0           NaN    NB    tfidf   fr  0.947667   0.911856  0.989892  0.949273
# 0           NaN    LR    tfidf   fr  0.989000   0.993972  0.984085  0.989004
# 0           NaN   MLP    tfidf   fr  0.998000   0.998649  0.997301  0.997974
# 0           NaN   SVM    tfidf   fr  0.997667   0.998004  0.997340  0.997672
# 0           NaN    NB    count   fr  0.933333   0.888682  0.985517  0.934598
# 0           NaN    LR    count   fr  0.994667   0.997299  0.991941  0.994613
# 0           NaN   MLP    count   fr  0.996667   0.998690  0.994781  0.996732
# 0           NaN   SVM    count   fr  0.994000   0.998639  0.989211  0.993902

# %%
metrics_df.groupby('model').mean().plot.bar(figsize = (12, 8))
plt.title('Comparación del desempeño de diferentes modelos', fontsize=20)
plt.ylabel('Porcentaje', fontsize=15)
plt.xlabel('Modelo', fontsize=15)
plt.grid(which='both')
plt.savefig('')

# %%
metrics_df.groupby('lang').mean().plot.bar(figsize = (12, 8))
plt.title('Comparación del desempeño en diferentes idiomas', fontsize=20)
plt.ylabel('Porcentaje', fontsize=15)
plt.xlabel('Idioma', fontsize=15)
plt.grid(which='both')
# plt.savefig('')

# %%
metrics_df.groupby('features').mean().plot.bar(figsize = (12, 8))
plt.title('Comparación del desempeño de extracción de caracterísicas', fontsize=20)
plt.ylabel('Porcentaje', fontsize=15)
plt.xlabel('Extracción de características', fontsize=15)
plt.grid(which='both')
# plt.savefig('')
